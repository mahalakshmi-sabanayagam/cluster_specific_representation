# %%
 # Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from torchvision.datasets import MNIST, FashionMNIST
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid
from torchvision.utils import save_image, make_grid
from src.train import train_RBM, train_tensorRBM
from src.models import RBM
from src.plot import *
from src.data import image_data_loader

# %%
device = "cpu" #torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Matplotlib settings
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['mathtext.rm'] = 'serif'
mpl.rcParams['savefig.dpi'] = 600
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.formatter.limits'] = (-3, 3)
mpl.rcParams['axes.formatter.use_mathtext'] = True

mpl.rcParams['font.family'] = 'STIXGeneral'
mpl.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
mpl.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
mpl.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

mpl.rcParams['legend.fontsize'] = 23
mpl.rcParams['legend.labelspacing'] = 0.3
mpl.rcParams['legend.borderpad'] = 0.2
mpl.rcParams['legend.handlelength'] = 1.5

# %%
BATCH_SIZE = 64
train_loader, test_loader = image_data_loader(dataset="mnist", path = './data', batch_size = BATCH_SIZE, class_labels_list = [0,1], num_samples = 200, transform=None)
# Out:
# Number of total train and test samples  torch.Size([400]) torch.Size([200])

# %%
trbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=1, n_clusters=2, epochs=15, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-126.5861, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-192.7173, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-223.2699, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-179.7901, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-220.7374, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-261.2466, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-309.7101, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-377.4556, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-416.2713, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-511.2112, grad_fn=<DivBackward0>)
# epoch 10 loss tensor(-632.2039, grad_fn=<DivBackward0>)
# epoch 11 loss tensor(-688.9639, grad_fn=<DivBackward0>)
# epoch 12 loss tensor(-837.5032, grad_fn=<DivBackward0>)
# epoch 13 loss tensor(-912.9151, grad_fn=<DivBackward0>)
# epoch 14 loss tensor(-1030.3967, grad_fn=<DivBackward0>)

# %%
plot_rbm(trbm, train_loader, n_clusters=2, batch_size=BATCH_SIZE, figsize=3, savefile=1, fname="main_draft_5")

# %%
rbm, loss = train_RBM(train_loader, n_vis=784, n_hin=500, k=1, epochs=15, lr=0.001, device=device)
# Out:
# 	Epoch 1 	Average Loss:  tensor(-35.8292)
# 	Epoch 2 	Average Loss:  tensor(-34.3951)
# 	Epoch 3 	Average Loss:  tensor(-21.0113)
# 	Epoch 4 	Average Loss:  tensor(-18.6085)
# 	Epoch 5 	Average Loss:  tensor(-16.1923)
# 	Epoch 6 	Average Loss:  tensor(-12.7406)
# 	Epoch 7 	Average Loss:  tensor(-13.1363)
# 	Epoch 8 	Average Loss:  tensor(-13.9312)
# 	Epoch 9 	Average Loss:  tensor(-14.9764)
# 	Epoch 10 	Average Loss:  tensor(-13.5179)
# 	Epoch 11 	Average Loss:  tensor(-10.6214)
# 	Epoch 12 	Average Loss:  tensor(-8.5249)
# 	Epoch 13 	Average Loss:  tensor(-7.2677)
# 	Epoch 14 	Average Loss:  tensor(-7.5386)
# 	Epoch 15 	Average Loss:  tensor(-7.2853)

# %%
plot_rbm(rbm, train_loader, n_clusters=None, batch_size=BATCH_SIZE, figsize=3, savefile=1, fname="main_draft")

# %%
rbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=1, n_clusters=2, epochs=20, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-128.9867, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-185.3360, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-203.6097, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-194.2125, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-222.5937, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-285.5577, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-358.4551, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-397.7262, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-468.1418, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-571.1949, grad_fn=<DivBackward0>)
# epoch 10 loss tensor(-677.6090, grad_fn=<DivBackward0>)
# epoch 11 loss tensor(-810.3481, grad_fn=<DivBackward0>)
# epoch 12 loss tensor(-882.4911, grad_fn=<DivBackward0>)
# epoch 13 loss tensor(-1015.0394, grad_fn=<DivBackward0>)
# epoch 14 loss tensor(-1092.3042, grad_fn=<DivBackward0>)
# epoch 15 loss tensor(-1240.6613, grad_fn=<DivBackward0>)
# epoch 16 loss tensor(-1277.8506, grad_fn=<DivBackward0>)
# ...

# %%
rbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=2, n_clusters=2, epochs=15, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-148.5012, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-235.9667, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-208.5199, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-265.6014, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-281.6133, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-315.7131, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-371.0357, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-433.6638, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-532.3414, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-644.5423, grad_fn=<DivBackward0>)
# epoch 10 loss tensor(-701.9988, grad_fn=<DivBackward0>)
# epoch 11 loss tensor(-798.3901, grad_fn=<DivBackward0>)
# epoch 12 loss tensor(-896.6027, grad_fn=<DivBackward0>)
# epoch 13 loss tensor(-1025.3799, grad_fn=<DivBackward0>)
# epoch 14 loss tensor(-1182.6879, grad_fn=<DivBackward0>)

# %%
rbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=5, n_clusters=2, epochs=10, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-152.2577, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-323.0539, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-331.3680, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-333.5970, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-387.4689, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-414.5066, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-411.2298, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-499.0710, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-622.2601, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-630.8802, grad_fn=<DivBackward0>)

# %%
rbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=10, n_clusters=2, epochs=15, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-161.6343, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-335.9223, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-378.2510, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-381.7994, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-309.5074, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-388.2764, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-436.5855, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-393.7755, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-453.7153, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-532.1425, grad_fn=<DivBackward0>)
# epoch 10 loss tensor(-667.8469, grad_fn=<DivBackward0>)
# epoch 11 loss tensor(-766.3124, grad_fn=<DivBackward0>)
# epoch 12 loss tensor(-835.4348, grad_fn=<DivBackward0>)
# epoch 13 loss tensor(-965.2902, grad_fn=<DivBackward0>)
# epoch 14 loss tensor(-1054.1195, grad_fn=<DivBackward0>)

# %%
rbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=20, n_clusters=2, epochs=10, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-162.5094, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-336.5128, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-375.9822, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-402.1035, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-359.9828, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-337.8305, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-335.2066, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-390.3736, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-456.7210, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-518.6431, grad_fn=<DivBackward0>)

# %%
rbm, train_loss, clust_assign = train_tensorRBM(train_loader, n_vis=784, n_hin=500, k=5, n_clusters=2, epochs=10, lr=0.001, device=device)
# Out:
# epoch 0 loss tensor(-155.9730, grad_fn=<DivBackward0>)
# epoch 1 loss tensor(-326.6129, grad_fn=<DivBackward0>)
# epoch 2 loss tensor(-323.8077, grad_fn=<DivBackward0>)
# epoch 3 loss tensor(-281.5105, grad_fn=<DivBackward0>)
# epoch 4 loss tensor(-352.5969, grad_fn=<DivBackward0>)
# epoch 5 loss tensor(-386.9857, grad_fn=<DivBackward0>)
# epoch 6 loss tensor(-439.5547, grad_fn=<DivBackward0>)
# epoch 7 loss tensor(-443.9936, grad_fn=<DivBackward0>)
# epoch 8 loss tensor(-525.3397, grad_fn=<DivBackward0>)
# epoch 9 loss tensor(-585.0935, grad_fn=<DivBackward0>)
